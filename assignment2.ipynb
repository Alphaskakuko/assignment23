# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv("Employee.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# load the data into a pandas DataFrame
Employee = pd.read_csv("Employee.csv")

# use seaborn to create a box plot of distance from home by job role
sns.boxplot(x='JobRole', y='DistanceFromHome', hue='Attrition', data=Employee)

# use seaborn to create a violin plot of distance from home by job role
sns.violinplot(x='JobRole', y='DistanceFromHome', hue='Attrition', data=Employee)

# use seaborn to create a swarm plot of distance from home by job role
sns.swarmplot(x='JobRole', y='DistanceFromHome', hue='Attrition', data=Employee)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 63.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# load the data into a pandas DataFrame
Employee = pd.read_csv("Employee.csv")

# Create a new column for annual income
Employee['annual_income'] = Employee['MonthlyIncome']*12

# Use groupby to calculate the average annual income by education and attrition
average_income = Employee.groupby(['Education', 'Attrition'])['annual_income'].mean()

# Use seaborn to create a bar plot of the average annual income
sns.barplot(x='Education', y='annual_income', hue='Attrition', data=Employee, ci='sd')

# Print the average income
print(average_income)
# Out:
# Education  Attrition
# 1          No            71113.553957
#            Yes           52321.935484
# 2          No            79032.705882
#            Yes           51390.545455
# 3          No            82595.035941
#            Yes           57242.909091
# 4          No            85053.776471
#            Yes           64021.862069
# 5          No           102718.883721
#            Yes           70202.400000
# Name: annual_income, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# load the data into a pandas DataFrame
Employee = pd.read_csv("Employee.csv")

# use seaborn to create a box plot of distance from home by job role and attrition
sns.boxplot(x='JobRole', y='DistanceFromHome', hue='Attrition', data=employees)

# use seaborn to create a violin plot of distance from home by job role and attrition
sns.violinplot(x='JobRole', y='DistanceFromHome', hue='Attrition', data=Employee)

# use seaborn to create a swarm plot of distance from home by job role and attrition
sns.swarmplot(x='JobRole', y='DistanceFromHome', hue='Attrition', data=Employee)

# use seaborn to create a faceted plot of distance from home by job role and attrition
sns.catplot(x='JobRole', y='DistanceFromHome', hue='Attrition', col='Attrition', kind='swarm', data=Employee)

# use seaborn to create a heat map of distance from home by job role and attrition
heatmap_data = employees.pivot_table(values='DistanceFromHome', index='JobRole', columns='Attrition', aggfunc='count')
sns.heatmap(heatmap_data, annot=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 63.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# load the data into a pandas DataFrame
Employee = pd.read_csv("Employee.csv")

# Use groupby to calculate the average monthly income by education and attrition
average_income = Employee.groupby(['Education', 'Attrition'])['MonthlyIncome'].mean()

# Use seaborn to create a bar plot of the average monthly income
sns.barplot(x='Education', y='MonthlyIncome', hue='Attrition', data=Employee)

# Use seaborn to create a violin plot of the average monthly income
sns.violinplot(x='Education', y='MonthlyIncome', hue='Attrition', data=Employee, split=True)

# Use seaborn to create a swarm plot of the average monthly income
sns.swarmplot(x='Education', y='MonthlyIncome', hue='Attrition', data=employees)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 39.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 53.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 45.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Education', ylabel='MonthlyIncome'>
